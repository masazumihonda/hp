# %% [markdown]
# # Intensive lectures at RESCEU
# ## (17-19th April 2023)

# %% [markdown]
# # Extra hands-on: Adiabatic state preparation of vacuum in Schwingermodel with $\theta =0$
# ## (with open boundary condition)

# %% [markdown]
# ###  Import packages

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from qiskit import *
#%matplotlib inline

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Here take $\theta =0$ and $m=m_0 >0$ for simplicity

# %% [markdown]
# ## Now, explicit form of $H_A (t)$  is
# $$ H_A (t) = H_Z +H_{ZZ}  +\frac{t}{T}H_{XX} +\frac{t}{T}H_{YY} $$,
# $$ H_Z =\frac{m}{2}\sum_{n=1}^N (-1)^n Z_n
#          -\frac{J}{2}\sum_{n=1}^{N-1} (n\ {\rm mod}\ 2) \sum_{\ell=1}^n Z_\ell $$
# $$H_{ZZ}= \frac{J}{2} \sum_{n=2}^{N-1} \sum_{1<k<\ell <n} Z_k Z_\ell $$
# $$ H_{XX} = \frac{w}{2} \sum_{n=1}^{N-1} X_n X_{n+1} $$
# $$ H_{YY} = \frac{w}{2} \sum_{n=1}^{N-1} X_n X_{n+1} $$

# %% [markdown]
# ### Let us fix the other parameters

# %%
N=4
g=1.0
w=1.0
mass=1.0

# %% [markdown]
# ## Excercise 1: Draw a quantum circuit for constructing
# $$|{\rm vac}_A \rangle
# \equiv U(T) U(T-\delta t) \cdots U(2\delta t) U(\delta t) |{\rm vac_0} \rangle \quad {\rm with}\ \delta t=\frac{T}{M}$$
# ## for $T=1, M=2$ using Trotter decomposition (assuming $\delta t\ll 1$)

# %% [markdown]
# ### (Note $ \frac{t}{T}  = \frac{(j+1)\delta t}{T} =\frac{j+1}{M}   )$

# %% [markdown]
# ## Answer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Excersise 2: Compute expectation value of magnetization under approximate vacuum:
# $$ \frac{1}{2Na}\langle {\rm vac}_A | \sum_{n=1}^N (-1)^n Z_n |{\rm vac}_A \rangle $$
# ## for $T=100, M=500$ by 100000 shots
# ### (result by exact diagonalization: -0.7244853140752381)

# %% [markdown]
# ## Answer
